# %%
import numpy as np
import random
from collections import defaultdict
import matplotlib.pyplot as plt

# %% [markdown]
# ### Agents Initialization

# %%
class Sensor:
    def __init__(self, position):
        self.position = position  # (x, y) coordinates
        self.data = random.random()  # Simulated sensor data

    def generate_data(self):
        """Simulate new data generation at the sensor."""
        self.data = random.random()

class Alice:
    def __init__(self, id, position, power=1.0):
        self.id = id  # Unique identifier for Alice
        self.position = position  # (x, y) coordinates
        self.power = power  # Transmission power
        self.collected_data = None  # Data collected from Sensors
        self.aoi = 0  # Age of Information

    def adjust_power(self, new_power):
        """Adjust transmission power."""
        self.power = max(0, new_power)  # Ensure power is non-negative

    def collect_data(self, sensors, collection_range=15):
        """Collect data from nearby sensors."""
        for sensor in sensors:
            distance = np.linalg.norm(np.array(self.position) - np.array(sensor.position))
            if distance <= collection_range:
                self.collected_data = sensor.data
                sensor.generate_data()  # Simulate new data generation
                #print(f"Alice {self.id} collected data from Sensor at {sensor.position}.")
                return  # Stop after collecting from one sensor
        #print(f"Alice {self.id} found no sensors in range.")

    def send_data(self, bob, current_time, transmission_range=15):
        """Send data to Bob if within range."""
        if self.collected_data is None:
            #print(f"Alice {self.id} has no data to send.")
            return

        distance = np.linalg.norm(np.array(self.position) - np.array(bob.position))
        if distance <= transmission_range:
            bob.receive_data(self.collected_data)
            self.aoi = 0  # Reset AoI since data was sent
            self.collected_data = None  # Clear collected data

    def get_state(self, sensors, bobs, wardens):
        """Get the current state representation for Alice."""
        sensor_distances = [np.linalg.norm(np.array(self.position) - np.array(sensor.position)) for sensor in sensors]
        bob_distances = [np.linalg.norm(np.array(self.position) - np.array(bob.position)) for bob in bobs]
        warden_distances = [np.linalg.norm(np.array(self.position) - np.array(warden.position)) for warden in wardens]

        # State includes position, power, AoI, and proximity to Sensors, Bobs, and Wardens
        state = (
            self.position[0],  # x-coordinate
            self.position[1],  # y-coordinate
            self.power,         # Transmission power level
            self.aoi,           # Age of Information
            int(self.collected_data is not None),  # 1 if Alice has data, else 0
            *sensor_distances,  # Distances to Sensors
            *bob_distances,     # Distances to Bobs
            *warden_distances   # Distances to Wardens
        )
        return state

    def perform_action(self, action, sensors, bobs):
        """Perform an action based on RL decision."""
        # Action is expected to be a tuple (power_adjustment, movement, transmission_target)
        power_adjustment, movement, transmission_target = action

        # Adjust power
        self.adjust_power(self.power + power_adjustment)

        # Move based on the RL action (movement)
        self.move(movement)

        # Transmit data to the specified Bob (if valid)
        if transmission_target < len(bobs):
            self.send_data(bobs[transmission_target], current_time=0)  # Example current_time

    def move(self, direction):
        """Move Alice based on RL decision."""
        # Define movement options
        if direction == "UP":
            self.position = (self.position[0], self.position[1] + 1)
        elif direction == "DOWN":
            self.position = (self.position[0], self.position[1] - 1)
        elif direction == "LEFT":
            self.position = (self.position[0] - 1, self.position[1])
        elif direction == "RIGHT":
            self.position = (self.position[0] + 1, self.position[1])
        # Ensure the position is within the environment bounds (e.g., within map size)
        self.position = (max(0, min(self.position[0], 100)), max(0, min(self.position[1], 100)))  # Example bounds

class Bob:
    def __init__(self, position):
        self.position = position  # (x, y) coordinates
        self.received_data = None  # Latest data received

    def receive_data(self, data):
        """Receive data from Alice."""
        self.received_data = data
        #print(f"Bob at {self.position} received data: {data}")

class Warden:
    def __init__(self, position):
        self.position = position  # (x, y) coordinates

    def detect(self, alice, detection_threshold=0.5):
        distance = np.linalg.norm(np.array(alice.position) - np.array(self.position))
        detection_prob = np.exp(-distance / (alice.power + 1))  # Simplified detection model
        return detection_prob > detection_threshold

# %% [markdown]
# ### Environment Initialization

# %%
class Environment:
    """Environment class with Alices, Sensors, Bobs, and Wardens."""
    def __init__(self, map_size, num_alices, num_sensors, num_bobs, num_wardens, seed=42):
        self.map_size = map_size
        self.num_alices = num_alices
        self.num_sensors = num_sensors
        self.num_bobs = num_bobs
        self.num_wardens = num_wardens
        self.current_time = 0  # Current simulation time step
        self.max_time_steps = 100  # Maximum steps per episode

        # Set the random seed for reproducibility
        random.seed(seed)
        np.random.seed(seed)

        # Initialize entities
        self.alices = self.distribute_alices_evenly()
        self.sensors = self.distribute_sensors_randomly()
        self.bobs = self.distribute_bobs_randomly()
        self.wardens = self.distribute_wardens_randomly()

    def reset(self):
        """Reset the environment to its initial state."""
        self.current_time = 0
        self.alices = self.distribute_alices_evenly()
        self.sensors = self.distribute_sensors_randomly()
        self.bobs = self.distribute_bobs_randomly()
        self.wardens = self.distribute_wardens_randomly()
        # Return the initial states of all Alices
        return [alice.get_state(self.sensors, self.bobs, self.wardens) for alice in self.alices]

    def step(self, actions):
        total_reward = 0
        states_after_step = []
        done = False

        # Loop through each Alice to process the action
        for i, alice in enumerate(self.alices):
            # Perform the action assigned to this Alice
            action = actions[i]

            # Ensure action is a tuple, if not convert it to a tuple with default values
            if not isinstance(action, tuple):
                action = (0, 0, 0)  # Default tuple (power_adjustment, movement, transmission_target)
            
            #print(f"Alice {alice.id} performing action: {action}, Type of action: {type(action)}")

            # Perform the action with the updated action format
            alice.perform_action(action, self.sensors, self.bobs)

            # Check for detection by Wardens
            detected = any(warden.detect(alice) for warden in self.wardens)
            #if detected:
                #print(f"Warden detected transmission from Alice {alice.id}.")

            # Calculate reward for Alice based on actions and detection
            reward = self.calculate_reward(alice, detected)
            total_reward += reward
            #print(f"Alice {alice.id} state: {alice.get_state(self.sensors, self.bobs, self.wardens)}")
            #print(f"Alice {alice.id} reward: {reward}")

            # Get the updated state for Alice after the action
            state = alice.get_state(self.sensors, self.bobs, self.wardens)
            states_after_step.append(state)

        self.current_time += 1
        if self.current_time >= self.max_time_steps:
            done = True

        #print(f"Time step {self.current_time} complete. Total reward: {total_reward}.")
        return states_after_step, total_reward, done

    def distribute_alices_evenly(self):
        """Distribute Alices evenly across a grid."""
        alices = []
        positions = [
            (35, 35), (35, 65), (65, 35), (65, 65)  # Example positions for up to 4 Alices
        ]
        for i, pos in enumerate(positions[:self.num_alices]):
            alices.append(Alice(i + 1, pos))
        return alices

    def distribute_sensors_randomly(self):
        """Distribute sensors randomly across the grid."""
        sensors = []
        for _ in range(self.num_sensors):
            x = random.randint(25, self.map_size - 25)
            y = random.randint(25, self.map_size - 25)
            sensors.append(Sensor((x, y)))
        return sensors

    def distribute_bobs_randomly(self):
        """Distribute Bobs randomly across the grid."""
        bobs = []
        for _ in range(self.num_bobs):
            x = random.randint(25, self.map_size - 25)
            y = random.randint(25, self.map_size - 25)
            bobs.append(Bob((x, y)))
        return bobs

    def distribute_wardens_randomly(self):
        """Distribute Wardens randomly across the grid."""
        wardens = []
        for _ in range(self.num_wardens):
            x = random.randint(25, self.map_size - 25)
            y = random.randint(25, self.map_size - 25)
            wardens.append(Warden((x, y)))
        return wardens

    def calculate_reward(self, alice, detected):
        reward = 0

        # Reward for collecting data
        if alice.collected_data is not None:
            reward += 10  # Example reward value for collecting data

        # Reward for successful transmission (without detection)
        if alice.collected_data is None and not detected:
            reward += 20  # Alice transmitted successfully without detection

        # Penalty for being detected by the Warden
        if detected:
            reward -= 30  # Penalty for detection (e.g., Alice got caught)

        # Penalty for Age of Information (AoI)
        reward -= alice.aoi * 0.1  # Penalize AoI; the more outdated the data, the worse the reward

        # Penalty for unnecessary power usage
        reward -= alice.power * 0.5  # Penalize for excessive power usage

        return reward

# %% [markdown]
# ### QLearningAgent Initialization

# %%
class QLearningAgent:
    def __init__(self, num_actions, state_dim):
        self.num_actions = num_actions  # Number of actions Alice can take
        self.state_dim = state_dim  # Dimensions of state space (number of features in the state)
        
        # Initialize the Q-table (state-action values) as a defaultdict of zeros
        self.q_table = defaultdict(lambda: np.zeros(num_actions))

    def set_learning_rate(self, learning_rate):
        """Set the learning rate."""
        self.learning_rate = learning_rate
    
    def set_discount_factor(self, discount_factor):
        """Set the discount factor."""
        self.discount_factor = discount_factor
    
    def set_epsilon(self, epsilon):
        """Set the epsilon value for exploration."""
        self.epsilon = epsilon

    def get_learning_rate(self):
        """Get the learning rate."""
        return self.learning_rate
    
    def get_discount_factor(self):
        """Get the discount factor."""
        return self.discount_factor
    
    def get_epsilon(self):
        """Get the epsilon value for exploration."""
        return self.epsilon

    def action_to_index(self, action, num_bobs):
        """
        Convert the action tuple (power_adjustment, movement, transmission_target)
        into a single index to represent the action.
        """
        power_adjustment, movement, transmission_target = action

        # Normalize the power_adjustment and movement to positive integers
        power_adjustment_idx = power_adjustment + 1  # Now -1 -> 0, 0 -> 1, 1 -> 2
        movement_idx = movement + 1  # Now -1 -> 0, 0 -> 1, 1 -> 2
        
        # Calculate the index for the action in the Q-table
        action_index = power_adjustment_idx * 3 * num_bobs + movement_idx * num_bobs + transmission_target

        # Ensure the action index does not exceed the number of actions
        if action_index >= self.num_actions:
            raise ValueError(f"Action index {action_index} exceeds the number of available actions: {self.num_actions}")

        return action_index

    def choose_action(self, state, bobs):
        """
        Choose an action based on epsilon-greedy policy:
        - With probability epsilon, choose a random action (exploration).
        - With probability 1-epsilon, choose the best known action (exploitation).
        :param state: The current state of the agent.
        :param bobs: List of Bob objects.
        :return: action - a tuple (power_adjustment, movement, transmission_target)
        """
        if random.uniform(0, 1) < self.epsilon:
            # Exploration: Choose a random action
            power_adjustment = random.choice([-1, 0, 1])  # Adjust power by -1, 0, or +1
            movement = random.choice([-1, 0, 1])  # Adjust movement in x or y direction
            transmission_target = random.randint(0, len(bobs) - 1)  # Randomly select a Bob to transmit to
        else:
            # Exploitation: Choose the best known action (based on max Q-value for current state)
            action_index = np.argmax(self.q_table[tuple(state)])  # Get index of the best action
            power_adjustment, movement, transmission_target = self.index_to_action(action_index, len(bobs))  # Convert index to action
        
        action = (power_adjustment, movement, transmission_target)
        return action

    def index_to_action(self, index, num_bobs):
        """
        Convert a Q-table index back into a corresponding action tuple (power_adjustment, movement, transmission_target).
        :param index: The index of the action in the Q-table.
        :param num_bobs: Number of Bobs to determine the transmission target range.
        :return: action - a tuple (power_adjustment, movement, transmission_target)
        """
        power_adjustment_idx = index // (3 * num_bobs)  # Find the power adjustment index
        movement_idx = (index % (3 * num_bobs)) // num_bobs  # Find the movement index
        transmission_target = index % num_bobs  # Find the transmission target

        # Convert indices back to values
        power_adjustment = power_adjustment_idx - 1  # Convert to range [-1, 0, 1]
        movement = movement_idx - 1  # Convert to range [-1, 0, 1]
        
        return (power_adjustment, movement, transmission_target)
    
    def update_q_value(self, state, action, reward, next_state, num_bobs):
        """Update the Q-value for a state-action pair using Q-learning update rule."""
        
        # Ensure state and next_state are tuples
        state = tuple(state)
        next_state = tuple(next_state)
        
        # Find the best action for the next state
        best_next_action = np.argmax(self.q_table[next_state])  # Best action for next state
        
        # Convert the action tuple to an index
        action_index = self.action_to_index(action, num_bobs)

        # Q-learning update rule
        self.q_table[state][action_index] = (self.q_table[state][action_index] + self.learning_rate * 
                                             (reward + self.discount_factor * self.q_table[next_state][best_next_action] - self.q_table[state][action_index]))

    def reset(self):
        """Reset the agent state if needed (optional)."""
        pass

# %% [markdown]
# ### Definining Parameters for Training

# %%
# Step 2: Define the environment and agent parameters
map_size = 100
num_alices = 4
num_sensors = 10
num_bobs = 4
num_wardens = 4
env = Environment(map_size, num_alices, num_sensors, num_bobs, num_wardens, seed=42)

# State and action dimensions for the QLearning agent
state_dim = 4 + 1 + num_sensors + num_bobs + num_wardens  # 4 for position, 1 for power, sensor_distances, bob_distances, warden_distances
num_actions = 3 * 3 * num_bobs  # 3 power adjustment actions (-1, 0, +1), num_bobs choices for transmission

# Initialize the QLearningAgent
agent = QLearningAgent(num_actions=num_actions, state_dim=state_dim)
# Set learning rate, discount factor, and epsilon externally
agent.set_learning_rate(0.001)
agent.set_discount_factor(0.99)
agent.set_epsilon(0.1)

# %% [markdown]
# ### Training Loop

# %%
num_episodes = 1000
reward_history = []

# Parameters for decay
epsilon_decay_rate = 0.99  # Decay rate for epsilon (exploration factor)
learning_rate_decay_rate = 0.995  # Decay rate for learning rate
min_epsilon = 0.01  # Minimum value for epsilon (ensures some exploration)
min_learning_rate = 0.0001  # Minimum value for learning rate

for episode in range(num_episodes):
    # Reset the environment at the start of each episode
    states = env.reset()  # This will get the initial states of all Alice agents
    total_reward = 0
    done = False

    while not done:
        actions = []
        next_states = []
        
        # Collect actions from each Alice (agent will decide based on state)
        for i, alice in enumerate(env.alices):
            state = alice.get_state(env.sensors, env.bobs, env.wardens)  # Get the current state of Alice

            # Convert state to a tuple if it's a list (to ensure it's hashable)
            state_tuple = tuple(state)  # Convert the state to a tuple

            # Get the action from the Q-learning agent based on the current state
            action = agent.choose_action(state_tuple, env.bobs)  # Choose an action (power_adjustment, movement, transmission_target)
            actions.append(action)

        # Step through the environment with the chosen actions
        next_states, reward, done = env.step(actions)  # Apply the actions and get new states, reward, and termination status

        # Update Q-values for each Alice (agent) based on the observed reward
        for i, alice in enumerate(env.alices):
            state = alice.get_state(env.sensors, env.bobs, env.wardens)
            state_tuple = tuple(state)  # Convert state to a tuple
            agent.update_q_value(state_tuple, actions[i], reward, next_states[i], len(env.bobs))  # Update Q-values with the reward and next state
        
        total_reward += reward
        
        # If episode reaches maximum time steps, stop the episode
        if done:
            break
    
    # Store the total reward for this episode
    reward_history.append(total_reward)
    print(f"Episode {episode + 1}/{num_episodes} - Total Reward: {total_reward}")

    # Apply epsilon decay
    epsilon = max(min_epsilon, agent.get_epsilon() * epsilon_decay_rate)  # Decay epsilon for exploration
    agent.set_epsilon(epsilon)

    # Apply learning rate decay
    learning_rate = max(min_learning_rate, agent.get_learning_rate() * learning_rate_decay_rate)  # Decay learning rate
    agent.set_learning_rate(learning_rate)
# Out:
# Episode 1/1000 - Total Reward: 2705.0
# Episode 2/1000 - Total Reward: 4780.5
# Episode 3/1000 - Total Reward: 1500.0
# Episode 4/1000 - Total Reward: 3994.0
# Episode 5/1000 - Total Reward: 3220.0
# Episode 6/1000 - Total Reward: -1213.5
# Episode 7/1000 - Total Reward: 1960.0
# Episode 8/1000 - Total Reward: 3528.5
# Episode 9/1000 - Total Reward: 2566.5
# Episode 10/1000 - Total Reward: 4030.5
# Episode 11/1000 - Total Reward: 3312.5
# Episode 12/1000 - Total Reward: 2924.0
# Episode 13/1000 - Total Reward: 1666.0
# Episode 14/1000 - Total Reward: 2029.5
# Episode 15/1000 - Total Reward: 3832.0
# Episode 16/1000 - Total Reward: 4860.5
# Episode 17/1000 - Total Reward: 2472.0
# Episode 18/1000 - Total Reward: 1731.0
# Episode 19/1000 - Total Reward: 3682.5
# Episode 20/1000 - Total Reward: 1381.0
# Episode 21/1000 - Total Reward: 3557.0
# Episode 22/1000 - Total Reward: 2938.5
# Episode 23/1000 - Total Reward: 3970.0
# Episode 24/1000 - Total Reward: 1571.0
# Episode 25/1000 - Total Reward: 4585.0
# Episode 26/1000 - Total Reward: 1830.5
# Episode 27/1000 - Total Reward: 5376.0
# Episode 28/1000 - Total Reward: 3882.5
# Episode 29/1000 - Total Reward: 2033.5
# Episode 30/1000 - Total Reward: 5600.5
# Episode 31/1000 - Total Reward: 3274.5
# Episode 32/1000 - Total Reward: 1472.0
# Episode 33/1000 - Total Reward: 2269.5
# Episode 34/1000 - Total Reward: 1469.0
# Episode 35/1000 - Total Reward: 3978.0
# Episode 36/1000 - Total Reward: 2550.5
# Episode 37/1000 - Total Reward: 1290.0
# Episode 38/1000 - Total Reward: 3485.0
# Episode 39/1000 - Total Reward: 2320.5
# Episode 40/1000 - Total Reward: 1230.5
# Episode 41/1000 - Total Reward: 3277.0
# Episode 42/1000 - Total Reward: 4774.0
# Episode 43/1000 - Total Reward: 5242.5
# Episode 44/1000 - Total Reward: 3077.5
# Episode 45/1000 - Total Reward: 4823.5
# Episode 46/1000 - Total Reward: 2781.0
# Episode 47/1000 - Total Reward: 1741.5
# Episode 48/1000 - Total Reward: 6170.5
# Episode 49/1000 - Total Reward: 5143.5
# Episode 50/1000 - Total Reward: 3294.0
# Episode 51/1000 - Total Reward: 2780.5
# Episode 52/1000 - Total Reward: 1751.5
# Episode 53/1000 - Total Reward: 1235.5
# Episode 54/1000 - Total Reward: 1817.0
# Episode 55/1000 - Total Reward: 2144.0
# Episode 56/1000 - Total Reward: 2784.5
# Episode 57/1000 - Total Reward: 1917.5
# Episode 58/1000 - Total Reward: 3937.5
# Episode 59/1000 - Total Reward: 1023.5
# Episode 60/1000 - Total Reward: 1721.0
# Episode 61/1000 - Total Reward: 5269.0
# Episode 62/1000 - Total Reward: 1257.0
# Episode 63/1000 - Total Reward: 1972.5
# Episode 64/1000 - Total Reward: 1695.0
# Episode 65/1000 - Total Reward: 1133.0
# Episode 66/1000 - Total Reward: 2762.0
# Episode 67/1000 - Total Reward: 6005.0
# Episode 68/1000 - Total Reward: 1715.5
# Episode 69/1000 - Total Reward: 5405.0
# Episode 70/1000 - Total Reward: 5769.0
# Episode 71/1000 - Total Reward: 3142.5
# Episode 72/1000 - Total Reward: 1656.5
# Episode 73/1000 - Total Reward: 2479.5
# Episode 74/1000 - Total Reward: 2675.0
# Episode 75/1000 - Total Reward: 2750.5
# Episode 76/1000 - Total Reward: 7006.0
# Episode 77/1000 - Total Reward: 1959.5
# Episode 78/1000 - Total Reward: 6211.0
# Episode 79/1000 - Total Reward: 2783.0
# Episode 80/1000 - Total Reward: 3952.5
# Episode 81/1000 - Total Reward: 7919.0
# Episode 82/1000 - Total Reward: 4653.0
# Episode 83/1000 - Total Reward: 3852.0
# Episode 84/1000 - Total Reward: 4425.5
# Episode 85/1000 - Total Reward: 6208.5
# Episode 86/1000 - Total Reward: 2962.0
# Episode 87/1000 - Total Reward: 3940.5
# Episode 88/1000 - Total Reward: 5684.0
# Episode 89/1000 - Total Reward: 7177.5
# Episode 90/1000 - Total Reward: 2366.0
# Episode 91/1000 - Total Reward: 5936.0
# Episode 92/1000 - Total Reward: 5065.5
# Episode 93/1000 - Total Reward: 3214.5
# Episode 94/1000 - Total Reward: 1645.0
# Episode 95/1000 - Total Reward: 8000.0
# Episode 96/1000 - Total Reward: 6309.0
# Episode 97/1000 - Total Reward: 2644.5
# Episode 98/1000 - Total Reward: 2035.0
# Episode 99/1000 - Total Reward: 1712.5
# Episode 100/1000 - Total Reward: 3489.5
# Episode 101/1000 - Total Reward: 4861.5
# Episode 102/1000 - Total Reward: 7046.5
# Episode 103/1000 - Total Reward: 6559.5
# Episode 104/1000 - Total Reward: 1380.0
# Episode 105/1000 - Total Reward: 2573.5
# Episode 106/1000 - Total Reward: 4049.5
# Episode 107/1000 - Total Reward: 3825.5
# Episode 108/1000 - Total Reward: 5962.0
# Episode 109/1000 - Total Reward: 2504.0
# Episode 110/1000 - Total Reward: 1582.5
# Episode 111/1000 - Total Reward: 7507.5
# Episode 112/1000 - Total Reward: 2353.0
# Episode 113/1000 - Total Reward: 6045.0
# Episode 114/1000 - Total Reward: 4000.5
# Episode 115/1000 - Total Reward: 1985.0
# Episode 116/1000 - Total Reward: 1071.0
# Episode 117/1000 - Total Reward: 7149.0
# Episode 118/1000 - Total Reward: 6491.5
# Episode 119/1000 - Total Reward: 6099.5
# Episode 120/1000 - Total Reward: 1355.0
# Episode 121/1000 - Total Reward: 2589.5
# Episode 122/1000 - Total Reward: 5362.0
# Episode 123/1000 - Total Reward: 2017.0
# Episode 124/1000 - Total Reward: 6035.0
# Episode 125/1000 - Total Reward: 3009.0
# Episode 126/1000 - Total Reward: 7016.0
# Episode 127/1000 - Total Reward: 1908.0
# Episode 128/1000 - Total Reward: 2814.5
# Episode 129/1000 - Total Reward: 5234.0
# Episode 130/1000 - Total Reward: 5916.5
# Episode 131/1000 - Total Reward: 4486.0
# Episode 132/1000 - Total Reward: 7574.5
# Episode 133/1000 - Total Reward: 5490.0
# Episode 134/1000 - Total Reward: 6092.5
# Episode 135/1000 - Total Reward: 4544.5
# Episode 136/1000 - Total Reward: 4798.5
# Episode 137/1000 - Total Reward: 3045.0
# Episode 138/1000 - Total Reward: 5763.0
# Episode 139/1000 - Total Reward: 1685.5
# Episode 140/1000 - Total Reward: 6190.0
# Episode 141/1000 - Total Reward: 3605.0
# Episode 142/1000 - Total Reward: 7967.0
# Episode 143/1000 - Total Reward: 3330.5
# Episode 144/1000 - Total Reward: 2422.0
# Episode 145/1000 - Total Reward: 4923.5
# Episode 146/1000 - Total Reward: 5235.5
# Episode 147/1000 - Total Reward: 7800.5
# Episode 148/1000 - Total Reward: 7856.0
# Episode 149/1000 - Total Reward: 7820.5
# Episode 150/1000 - Total Reward: 2320.5
# Episode 151/1000 - Total Reward: 3026.0
# Episode 152/1000 - Total Reward: 5075.5
# Episode 153/1000 - Total Reward: 7316.0
# Episode 154/1000 - Total Reward: 3136.0
# Episode 155/1000 - Total Reward: 2613.5
# Episode 156/1000 - Total Reward: 2728.5
# Episode 157/1000 - Total Reward: 5380.5
# Episode 158/1000 - Total Reward: 2680.5
# Episode 159/1000 - Total Reward: 7997.0
# Episode 160/1000 - Total Reward: 8000.0
# Episode 161/1000 - Total Reward: 4168.0
# Episode 162/1000 - Total Reward: 1789.5
# Episode 163/1000 - Total Reward: 7992.5
# Episode 164/1000 - Total Reward: 3817.5
# Episode 165/1000 - Total Reward: 6105.0
# Episode 166/1000 - Total Reward: 7200.5
# Episode 167/1000 - Total Reward: 6186.0
# Episode 168/1000 - Total Reward: 3298.0
# Episode 169/1000 - Total Reward: 8000.0
# Episode 170/1000 - Total Reward: 3390.0
# Episode 171/1000 - Total Reward: 4381.5
# Episode 172/1000 - Total Reward: 5756.5
# Episode 173/1000 - Total Reward: 5507.5
# Episode 174/1000 - Total Reward: 4980.0
# Episode 175/1000 - Total Reward: 8000.0
# Episode 176/1000 - Total Reward: 4063.0
# Episode 177/1000 - Total Reward: 2473.0
# Episode 178/1000 - Total Reward: 1588.0
# Episode 179/1000 - Total Reward: 5117.0
# Episode 180/1000 - Total Reward: 7189.5
# Episode 181/1000 - Total Reward: 7305.5
# Episode 182/1000 - Total Reward: 3750.5
# Episode 183/1000 - Total Reward: 7502.5
# Episode 184/1000 - Total Reward: 8000.0
# Episode 185/1000 - Total Reward: 2317.0
# Episode 186/1000 - Total Reward: 3201.5
# Episode 187/1000 - Total Reward: 5042.5
# Episode 188/1000 - Total Reward: 7712.0
# Episode 189/1000 - Total Reward: 3352.0
# Episode 190/1000 - Total Reward: 4289.5
# Episode 191/1000 - Total Reward: 7872.5
# Episode 192/1000 - Total Reward: 2978.0
# Episode 193/1000 - Total Reward: 7973.5
# Episode 194/1000 - Total Reward: 8000.0
# Episode 195/1000 - Total Reward: 8000.0
# Episode 196/1000 - Total Reward: 6874.5
# Episode 197/1000 - Total Reward: 4844.5
# Episode 198/1000 - Total Reward: 6094.5
# Episode 199/1000 - Total Reward: 2412.5
# Episode 200/1000 - Total Reward: 5888.0
# Episode 201/1000 - Total Reward: 6191.0
# Episode 202/1000 - Total Reward: 6497.5
# Episode 203/1000 - Total Reward: 7982.0
# Episode 204/1000 - Total Reward: 4916.0
# Episode 205/1000 - Total Reward: 1579.5
# Episode 206/1000 - Total Reward: 7269.5
# Episode 207/1000 - Total Reward: 7987.5
# Episode 208/1000 - Total Reward: 3311.5
# Episode 209/1000 - Total Reward: 5511.0
# Episode 210/1000 - Total Reward: 5069.5
# Episode 211/1000 - Total Reward: 6702.0
# Episode 212/1000 - Total Reward: 5702.5
# Episode 213/1000 - Total Reward: 6063.0
# Episode 214/1000 - Total Reward: 7823.5
# Episode 215/1000 - Total Reward: 7987.0
# Episode 216/1000 - Total Reward: 2060.0
# Episode 217/1000 - Total Reward: 5421.0
# Episode 218/1000 - Total Reward: 8000.0
# Episode 219/1000 - Total Reward: 6929.5
# Episode 220/1000 - Total Reward: 8000.0
# Episode 221/1000 - Total Reward: 8000.0
# Episode 222/1000 - Total Reward: 5431.5
# Episode 223/1000 - Total Reward: 7954.5
# Episode 224/1000 - Total Reward: 8000.0
# Episode 225/1000 - Total Reward: 6474.5
# Episode 226/1000 - Total Reward: 3196.5
# Episode 227/1000 - Total Reward: 8000.0
# Episode 228/1000 - Total Reward: 8000.0
# Episode 229/1000 - Total Reward: 2242.5
# Episode 230/1000 - Total Reward: 7980.0
# Episode 231/1000 - Total Reward: 4230.5
# Episode 232/1000 - Total Reward: 8000.0
# Episode 233/1000 - Total Reward: 8000.0
# Episode 234/1000 - Total Reward: 8000.0
# Episode 235/1000 - Total Reward: 5965.5
# Episode 236/1000 - Total Reward: 5609.5
# Episode 237/1000 - Total Reward: 7975.5
# Episode 238/1000 - Total Reward: 8000.0
# Episode 239/1000 - Total Reward: 3380.5
# Episode 240/1000 - Total Reward: 6835.0
# Episode 241/1000 - Total Reward: 3365.5
# Episode 242/1000 - Total Reward: 4332.5
# Episode 243/1000 - Total Reward: 5725.5
# Episode 244/1000 - Total Reward: 8000.0
# Episode 245/1000 - Total Reward: 7999.5
# Episode 246/1000 - Total Reward: 8000.0
# Episode 247/1000 - Total Reward: 5731.0
# Episode 248/1000 - Total Reward: 7790.0
# Episode 249/1000 - Total Reward: 7822.0
# Episode 250/1000 - Total Reward: 8000.0
# Episode 251/1000 - Total Reward: 5537.5
# Episode 252/1000 - Total Reward: 2227.5
# Episode 253/1000 - Total Reward: 4434.5
# Episode 254/1000 - Total Reward: 2503.0
# Episode 255/1000 - Total Reward: 8000.0
# Episode 256/1000 - Total Reward: 8000.0
# Episode 257/1000 - Total Reward: 2818.5
# Episode 258/1000 - Total Reward: 8000.0
# Episode 259/1000 - Total Reward: 3667.0
# Episode 260/1000 - Total Reward: 7989.5
# Episode 261/1000 - Total Reward: 2812.5
# Episode 262/1000 - Total Reward: 1014.5
# Episode 263/1000 - Total Reward: 6759.5
# Episode 264/1000 - Total Reward: 2657.0
# Episode 265/1000 - Total Reward: 8000.0
# Episode 266/1000 - Total Reward: 5868.0
# Episode 267/1000 - Total Reward: 7826.0
# Episode 268/1000 - Total Reward: 8000.0
# Episode 269/1000 - Total Reward: 8000.0
# Episode 270/1000 - Total Reward: 8000.0
# Episode 271/1000 - Total Reward: 8000.0
# Episode 272/1000 - Total Reward: 6200.0
# Episode 273/1000 - Total Reward: 4242.0
# Episode 274/1000 - Total Reward: 3013.5
# Episode 275/1000 - Total Reward: 5068.0
# Episode 276/1000 - Total Reward: 7947.5
# Episode 277/1000 - Total Reward: 3070.0
# Episode 278/1000 - Total Reward: 7648.5
# Episode 279/1000 - Total Reward: 7657.0
# Episode 280/1000 - Total Reward: 4220.0
# Episode 281/1000 - Total Reward: 5839.0
# Episode 282/1000 - Total Reward: 7948.5
# Episode 283/1000 - Total Reward: 7967.0
# Episode 284/1000 - Total Reward: 5344.5
# Episode 285/1000 - Total Reward: 6767.5
# Episode 286/1000 - Total Reward: 6055.0
# Episode 287/1000 - Total Reward: 8000.0
# Episode 288/1000 - Total Reward: 7782.5
# Episode 289/1000 - Total Reward: 2455.5
# Episode 290/1000 - Total Reward: 7617.0
# Episode 291/1000 - Total Reward: 4535.0
# Episode 292/1000 - Total Reward: 8000.0
# Episode 293/1000 - Total Reward: 5144.0
# Episode 294/1000 - Total Reward: 5962.5
# Episode 295/1000 - Total Reward: 6888.0
# Episode 296/1000 - Total Reward: 1638.5
# Episode 297/1000 - Total Reward: 7914.5
# Episode 298/1000 - Total Reward: 8000.0
# Episode 299/1000 - Total Reward: 3595.0
# Episode 300/1000 - Total Reward: 2950.0
# Episode 301/1000 - Total Reward: 6332.5
# Episode 302/1000 - Total Reward: 4406.5
# Episode 303/1000 - Total Reward: 5706.0
# Episode 304/1000 - Total Reward: 8000.0
# Episode 305/1000 - Total Reward: 6609.5
# Episode 306/1000 - Total Reward: 5486.0
# Episode 307/1000 - Total Reward: 4673.0
# Episode 308/1000 - Total Reward: 8000.0
# Episode 309/1000 - Total Reward: 7947.5
# Episode 310/1000 - Total Reward: 5712.0
# Episode 311/1000 - Total Reward: 6541.0
# Episode 312/1000 - Total Reward: 7997.0
# Episode 313/1000 - Total Reward: 3660.0
# Episode 314/1000 - Total Reward: 2836.0
# Episode 315/1000 - Total Reward: 7217.0
# Episode 316/1000 - Total Reward: 7812.5
# Episode 317/1000 - Total Reward: 3633.0
# Episode 318/1000 - Total Reward: 6929.5
# Episode 319/1000 - Total Reward: 6885.5
# Episode 320/1000 - Total Reward: 6617.0
# Episode 321/1000 - Total Reward: 3814.0
# Episode 322/1000 - Total Reward: 7967.0
# Episode 323/1000 - Total Reward: 7923.5
# Episode 324/1000 - Total Reward: 8000.0
# Episode 325/1000 - Total Reward: 8000.0
# Episode 326/1000 - Total Reward: 7950.0
# Episode 327/1000 - Total Reward: 6481.0
# Episode 328/1000 - Total Reward: 8000.0
# Episode 329/1000 - Total Reward: 4955.5
# Episode 330/1000 - Total Reward: 3515.0
# Episode 331/1000 - Total Reward: 6124.0
# Episode 332/1000 - Total Reward: 3640.0
# Episode 333/1000 - Total Reward: 8000.0
# Episode 334/1000 - Total Reward: 7970.0
# Episode 335/1000 - Total Reward: 6567.5
# Episode 336/1000 - Total Reward: 7950.0
# Episode 337/1000 - Total Reward: 3556.5
# Episode 338/1000 - Total Reward: 5400.5
# Episode 339/1000 - Total Reward: 8000.0
# Episode 340/1000 - Total Reward: 8000.0
# Episode 341/1000 - Total Reward: 8000.0
# Episode 342/1000 - Total Reward: 4553.0
# Episode 343/1000 - Total Reward: 2970.5
# Episode 344/1000 - Total Reward: 6669.5
# Episode 345/1000 - Total Reward: 8000.0
# Episode 346/1000 - Total Reward: 8000.0
# Episode 347/1000 - Total Reward: 8000.0
# Episode 348/1000 - Total Reward: 2515.0
# Episode 349/1000 - Total Reward: 1890.5
# Episode 350/1000 - Total Reward: 4130.0
# Episode 351/1000 - Total Reward: 8000.0
# Episode 352/1000 - Total Reward: 8000.0
# Episode 353/1000 - Total Reward: 8000.0
# Episode 354/1000 - Total Reward: 7933.0
# Episode 355/1000 - Total Reward: 6162.5
# Episode 356/1000 - Total Reward: 8000.0
# Episode 357/1000 - Total Reward: 8000.0
# Episode 358/1000 - Total Reward: 5760.0
# Episode 359/1000 - Total Reward: 7514.0
# Episode 360/1000 - Total Reward: 7764.5
# Episode 361/1000 - Total Reward: 8000.0
# Episode 362/1000 - Total Reward: 8000.0
# Episode 363/1000 - Total Reward: 4972.5
# Episode 364/1000 - Total Reward: 2215.5
# Episode 365/1000 - Total Reward: 6898.5
# Episode 366/1000 - Total Reward: 8000.0
# Episode 367/1000 - Total Reward: 8000.0
# Episode 368/1000 - Total Reward: 4380.5
# Episode 369/1000 - Total Reward: 3510.0
# Episode 370/1000 - Total Reward: 4308.5
# Episode 371/1000 - Total Reward: 3407.5
# Episode 372/1000 - Total Reward: 7982.0
# Episode 373/1000 - Total Reward: 4292.5
# Episode 374/1000 - Total Reward: 7992.5
# Episode 375/1000 - Total Reward: 8000.0
# Episode 376/1000 - Total Reward: 3256.5
# Episode 377/1000 - Total Reward: 5808.5
# Episode 378/1000 - Total Reward: 6496.5
# Episode 379/1000 - Total Reward: 8000.0
# Episode 380/1000 - Total Reward: 8000.0
# Episode 381/1000 - Total Reward: 7986.0
# Episode 382/1000 - Total Reward: 5146.5
# Episode 383/1000 - Total Reward: 1850.0
# Episode 384/1000 - Total Reward: 2538.0
# Episode 385/1000 - Total Reward: 6382.5
# Episode 386/1000 - Total Reward: 8000.0
# Episode 387/1000 - Total Reward: 1936.0
# Episode 388/1000 - Total Reward: 1886.0
# Episode 389/1000 - Total Reward: 8000.0
# Episode 390/1000 - Total Reward: 8000.0
# Episode 391/1000 - Total Reward: 8000.0
# Episode 392/1000 - Total Reward: 8000.0
# Episode 393/1000 - Total Reward: 8000.0
# Episode 394/1000 - Total Reward: 4965.5
# Episode 395/1000 - Total Reward: 7932.0
# Episode 396/1000 - Total Reward: 7547.5
# Episode 397/1000 - Total Reward: 7932.0
# Episode 398/1000 - Total Reward: 7786.0
# Episode 399/1000 - Total Reward: 3550.5
# Episode 400/1000 - Total Reward: 8000.0
# Episode 401/1000 - Total Reward: 7823.5
# Episode 402/1000 - Total Reward: 4374.0
# Episode 403/1000 - Total Reward: 6260.0
# Episode 404/1000 - Total Reward: 5410.5
# Episode 405/1000 - Total Reward: 7986.0
# Episode 406/1000 - Total Reward: 2983.0
# Episode 407/1000 - Total Reward: 8000.0
# Episode 408/1000 - Total Reward: 5905.0
# Episode 409/1000 - Total Reward: 7464.5
# Episode 410/1000 - Total Reward: 8000.0
# Episode 411/1000 - Total Reward: 8000.0
# Episode 412/1000 - Total Reward: 4483.5
# Episode 413/1000 - Total Reward: 3650.5
# Episode 414/1000 - Total Reward: 4655.5
# Episode 415/1000 - Total Reward: 3041.5
# Episode 416/1000 - Total Reward: 8000.0
# Episode 417/1000 - Total Reward: 6442.0
# Episode 418/1000 - Total Reward: 8000.0
# Episode 419/1000 - Total Reward: 2064.5
# Episode 420/1000 - Total Reward: 4630.5
# Episode 421/1000 - Total Reward: 7775.0
# Episode 422/1000 - Total Reward: 8000.0
# Episode 423/1000 - Total Reward: 7190.0
# Episode 424/1000 - Total Reward: 3970.5
# Episode 425/1000 - Total Reward: 8000.0
# Episode 426/1000 - Total Reward: 8000.0
# Episode 427/1000 - Total Reward: 7989.5
# Episode 428/1000 - Total Reward: 8000.0
# Episode 429/1000 - Total Reward: 4122.0
# Episode 430/1000 - Total Reward: 8000.0
# Episode 431/1000 - Total Reward: 3270.0
# Episode 432/1000 - Total Reward: 1678.0
# Episode 433/1000 - Total Reward: 3148.0
# Episode 434/1000 - Total Reward: 7744.5
# Episode 435/1000 - Total Reward: 1836.0
# Episode 436/1000 - Total Reward: 8000.0
# Episode 437/1000 - Total Reward: 7887.5
# Episode 438/1000 - Total Reward: 8000.0
# Episode 439/1000 - Total Reward: 8000.0
# Episode 440/1000 - Total Reward: 3388.0
# Episode 441/1000 - Total Reward: 3006.0
# Episode 442/1000 - Total Reward: 7983.0
# Episode 443/1000 - Total Reward: 4308.0
# Episode 444/1000 - Total Reward: 4377.0
# Episode 445/1000 - Total Reward: 6790.0
# Episode 446/1000 - Total Reward: 3782.0
# Episode 447/1000 - Total Reward: 7312.0
# Episode 448/1000 - Total Reward: 6836.5
# Episode 449/1000 - Total Reward: 8000.0
# Episode 450/1000 - Total Reward: 8000.0
# Episode 451/1000 - Total Reward: 5676.5
# Episode 452/1000 - Total Reward: 6595.0
# Episode 453/1000 - Total Reward: 7175.0
# Episode 454/1000 - Total Reward: 8000.0
# Episode 455/1000 - Total Reward: 4483.0
# Episode 456/1000 - Total Reward: 7977.5
# Episode 457/1000 - Total Reward: 8000.0
# Episode 458/1000 - Total Reward: 2846.0
# Episode 459/1000 - Total Reward: 6749.5
# Episode 460/1000 - Total Reward: 4997.0
# Episode 461/1000 - Total Reward: 3901.0
# Episode 462/1000 - Total Reward: 8000.0
# Episode 463/1000 - Total Reward: 7100.0
# Episode 464/1000 - Total Reward: 8000.0
# Episode 465/1000 - Total Reward: 7767.5
# Episode 466/1000 - Total Reward: 4867.5
# Episode 467/1000 - Total Reward: 5987.0
# Episode 468/1000 - Total Reward: 3394.5
# Episode 469/1000 - Total Reward: 8000.0
# Episode 470/1000 - Total Reward: 8000.0
# Episode 471/1000 - Total Reward: 6172.0
# Episode 472/1000 - Total Reward: 6100.0
# Episode 473/1000 - Total Reward: 6507.0
# Episode 474/1000 - Total Reward: 6649.0
# Episode 475/1000 - Total Reward: 3654.5
# Episode 476/1000 - Total Reward: 6236.0
# Episode 477/1000 - Total Reward: 5259.0
# Episode 478/1000 - Total Reward: 7949.5
# Episode 479/1000 - Total Reward: 3139.0
# Episode 480/1000 - Total Reward: 5051.5
# Episode 481/1000 - Total Reward: 7977.5
# Episode 482/1000 - Total Reward: 7546.5
# Episode 483/1000 - Total Reward: 5380.0
# Episode 484/1000 - Total Reward: 5400.0
# Episode 485/1000 - Total Reward: 8000.0
# Episode 486/1000 - Total Reward: 6490.0
# Episode 487/1000 - Total Reward: 1856.5
# Episode 488/1000 - Total Reward: 4192.0
# Episode 489/1000 - Total Reward: 8000.0
# Episode 490/1000 - Total Reward: 1014.0
# Episode 491/1000 - Total Reward: 8000.0
# Episode 492/1000 - Total Reward: 2997.5
# Episode 493/1000 - Total Reward: 5865.0
# Episode 494/1000 - Total Reward: 3903.5
# Episode 495/1000 - Total Reward: 8000.0
# Episode 496/1000 - Total Reward: 5365.0
# Episode 497/1000 - Total Reward: 7832.0
# Episode 498/1000 - Total Reward: 8000.0
# Episode 499/1000 - Total Reward: 8000.0
# Episode 500/1000 - Total Reward: 3004.5
# Episode 501/1000 - Total Reward: 2855.0
# Episode 502/1000 - Total Reward: 7968.0
# Episode 503/1000 - Total Reward: 8000.0
# Episode 504/1000 - Total Reward: 7809.5
# Episode 505/1000 - Total Reward: 7523.0
# Episode 506/1000 - Total Reward: 8000.0
# Episode 507/1000 - Total Reward: 2832.5
# Episode 508/1000 - Total Reward: 3913.5
# Episode 509/1000 - Total Reward: 8000.0
# Episode 510/1000 - Total Reward: 5862.5
# Episode 511/1000 - Total Reward: 7862.0
# Episode 512/1000 - Total Reward: 8000.0
# Episode 513/1000 - Total Reward: 6605.0
# Episode 514/1000 - Total Reward: 4907.0
# Episode 515/1000 - Total Reward: 5748.5
# Episode 516/1000 - Total Reward: 5012.5
# Episode 517/1000 - Total Reward: 7502.0
# Episode 518/1000 - Total Reward: 4333.0
# Episode 519/1000 - Total Reward: 5185.0
# Episode 520/1000 - Total Reward: 3573.0
# Episode 521/1000 - Total Reward: 8000.0
# Episode 522/1000 - Total Reward: 1172.0
# Episode 523/1000 - Total Reward: 7448.5
# Episode 524/1000 - Total Reward: 8000.0
# Episode 525/1000 - Total Reward: 4557.5
# Episode 526/1000 - Total Reward: 5274.5
# Episode 527/1000 - Total Reward: 8000.0
# Episode 528/1000 - Total Reward: 7137.0
# Episode 529/1000 - Total Reward: 6373.5
# Episode 530/1000 - Total Reward: 7085.0
# Episode 531/1000 - Total Reward: 7954.5
# Episode 532/1000 - Total Reward: 3251.5
# Episode 533/1000 - Total Reward: 5286.0
# Episode 534/1000 - Total Reward: 7989.5
# Episode 535/1000 - Total Reward: 2305.0
# Episode 536/1000 - Total Reward: 7395.5
# Episode 537/1000 - Total Reward: 8000.0
# Episode 538/1000 - Total Reward: 8000.0
# Episode 539/1000 - Total Reward: 1934.5
# Episode 540/1000 - Total Reward: 5748.5
# Episode 541/1000 - Total Reward: 8000.0
# Episode 542/1000 - Total Reward: 7947.5
# Episode 543/1000 - Total Reward: 2756.0
# Episode 544/1000 - Total Reward: 6755.0
# Episode 545/1000 - Total Reward: 6487.5
# Episode 546/1000 - Total Reward: 2714.0
# Episode 547/1000 - Total Reward: 8000.0
# Episode 548/1000 - Total Reward: 5290.5
# Episode 549/1000 - Total Reward: 5605.0
# Episode 550/1000 - Total Reward: 3740.5
# Episode 551/1000 - Total Reward: 3551.5
# Episode 552/1000 - Total Reward: 7767.5
# Episode 553/1000 - Total Reward: 1508.5
# Episode 554/1000 - Total Reward: 7967.0
# Episode 555/1000 - Total Reward: 8000.0
# Episode 556/1000 - Total Reward: 8000.0
# Episode 557/1000 - Total Reward: 4251.5
# Episode 558/1000 - Total Reward: 6190.0
# Episode 559/1000 - Total Reward: 8000.0
# Episode 560/1000 - Total Reward: 5782.5
# Episode 561/1000 - Total Reward: 7997.0
# Episode 562/1000 - Total Reward: 8000.0
# Episode 563/1000 - Total Reward: 6027.0
# Episode 564/1000 - Total Reward: 3430.5
# Episode 565/1000 - Total Reward: 7859.0
# Episode 566/1000 - Total Reward: 2878.0
# Episode 567/1000 - Total Reward: 3121.0
# Episode 568/1000 - Total Reward: 2395.5
# Episode 569/1000 - Total Reward: 7503.5
# Episode 570/1000 - Total Reward: 7989.5
# Episode 571/1000 - Total Reward: 3043.5
# Episode 572/1000 - Total Reward: 7936.0
# Episode 573/1000 - Total Reward: 7177.5
# Episode 574/1000 - Total Reward: 4812.5
# Episode 575/1000 - Total Reward: 4645.5
# Episode 576/1000 - Total Reward: 5176.5
# Episode 577/1000 - Total Reward: 8000.0
# Episode 578/1000 - Total Reward: 6549.5
# Episode 579/1000 - Total Reward: 7223.5
# Episode 580/1000 - Total Reward: 6436.0
# Episode 581/1000 - Total Reward: 8000.0
# Episode 582/1000 - Total Reward: 8000.0
# Episode 583/1000 - Total Reward: 6161.0
# Episode 584/1000 - Total Reward: 8000.0
# Episode 585/1000 - Total Reward: 4500.5
# Episode 586/1000 - Total Reward: 6816.0
# Episode 587/1000 - Total Reward: 4620.0
# Episode 588/1000 - Total Reward: 5996.0
# Episode 589/1000 - Total Reward: 1989.5
# Episode 590/1000 - Total Reward: 6320.0
# Episode 591/1000 - Total Reward: 7927.5
# Episode 592/1000 - Total Reward: 8000.0
# Episode 593/1000 - Total Reward: 8000.0
# Episode 594/1000 - Total Reward: 8000.0
# Episode 595/1000 - Total Reward: 8000.0
# Episode 596/1000 - Total Reward: 7977.5
# Episode 597/1000 - Total Reward: 8000.0
# Episode 598/1000 - Total Reward: 7704.5
# Episode 599/1000 - Total Reward: 7629.5
# Episode 600/1000 - Total Reward: 4617.0
# Episode 601/1000 - Total Reward: 6835.0
# Episode 602/1000 - Total Reward: 4923.0
# Episode 603/1000 - Total Reward: 6315.0
# Episode 604/1000 - Total Reward: 6551.5
# Episode 605/1000 - Total Reward: 4364.5
# Episode 606/1000 - Total Reward: 8000.0
# Episode 607/1000 - Total Reward: 2350.0
# Episode 608/1000 - Total Reward: 8000.0
# Episode 609/1000 - Total Reward: 8000.0
# Episode 610/1000 - Total Reward: 6023.5
# Episode 611/1000 - Total Reward: 7998.5
# Episode 612/1000 - Total Reward: 4065.5
# Episode 613/1000 - Total Reward: 4672.0
# Episode 614/1000 - Total Reward: 5012.5
# Episode 615/1000 - Total Reward: 8000.0
# Episode 616/1000 - Total Reward: 3297.5
# Episode 617/1000 - Total Reward: 4858.5
# Episode 618/1000 - Total Reward: 5044.5
# Episode 619/1000 - Total Reward: 7904.5
# Episode 620/1000 - Total Reward: 6856.5
# Episode 621/1000 - Total Reward: 8000.0
# Episode 622/1000 - Total Reward: 4238.0
# Episode 623/1000 - Total Reward: 7986.0
# Episode 624/1000 - Total Reward: 2546.5
# Episode 625/1000 - Total Reward: 4380.0
# Episode 626/1000 - Total Reward: 3981.5
# Episode 627/1000 - Total Reward: 7147.0
# Episode 628/1000 - Total Reward: 3451.5
# Episode 629/1000 - Total Reward: 8000.0
# Episode 630/1000 - Total Reward: 8000.0
# Episode 631/1000 - Total Reward: 5630.5
# Episode 632/1000 - Total Reward: 5407.5
# Episode 633/1000 - Total Reward: 3188.0
# Episode 634/1000 - Total Reward: 4498.0
# Episode 635/1000 - Total Reward: 7505.0
# Episode 636/1000 - Total Reward: 1304.5
# Episode 637/1000 - Total Reward: 4612.5
# Episode 638/1000 - Total Reward: 8000.0
# Episode 639/1000 - Total Reward: 5052.5
# Episode 640/1000 - Total Reward: 1881.0
# Episode 641/1000 - Total Reward: 8000.0
# Episode 642/1000 - Total Reward: 7656.5
# Episode 643/1000 - Total Reward: 5132.5
# Episode 644/1000 - Total Reward: 6325.0
# Episode 645/1000 - Total Reward: 7882.5
# Episode 646/1000 - Total Reward: 7920.5
# Episode 647/1000 - Total Reward: 6397.0
# Episode 648/1000 - Total Reward: 4847.5
# Episode 649/1000 - Total Reward: 4602.0
# Episode 650/1000 - Total Reward: 8000.0
# Episode 651/1000 - Total Reward: 5906.5
# Episode 652/1000 - Total Reward: 8000.0
# Episode 653/1000 - Total Reward: 6724.0
# Episode 654/1000 - Total Reward: 8000.0
# Episode 655/1000 - Total Reward: 5576.5
# Episode 656/1000 - Total Reward: 7982.0
# Episode 657/1000 - Total Reward: 7195.5
# Episode 658/1000 - Total Reward: 8000.0
# Episode 659/1000 - Total Reward: 4917.5
# Episode 660/1000 - Total Reward: 7688.0
# Episode 661/1000 - Total Reward: 6612.0
# Episode 662/1000 - Total Reward: 4934.5
# Episode 663/1000 - Total Reward: 2103.5
# Episode 664/1000 - Total Reward: 7961.0
# Episode 665/1000 - Total Reward: 8000.0
# Episode 666/1000 - Total Reward: 2760.5
# Episode 667/1000 - Total Reward: 2130.0
# Episode 668/1000 - Total Reward: 7453.5
# Episode 669/1000 - Total Reward: 6597.0
# Episode 670/1000 - Total Reward: 6928.0
# Episode 671/1000 - Total Reward: 8000.0
# Episode 672/1000 - Total Reward: 2880.0
# Episode 673/1000 - Total Reward: 5281.0
# Episode 674/1000 - Total Reward: 6150.0
# Episode 675/1000 - Total Reward: 7998.5
# Episode 676/1000 - Total Reward: 8000.0
# Episode 677/1000 - Total Reward: 7420.0
# Episode 678/1000 - Total Reward: 7905.0
# Episode 679/1000 - Total Reward: 2112.5
# Episode 680/1000 - Total Reward: 8000.0
# Episode 681/1000 - Total Reward: 5977.5
# Episode 682/1000 - Total Reward: 2002.0
# Episode 683/1000 - Total Reward: 2764.0
# Episode 684/1000 - Total Reward: 5702.0
# Episode 685/1000 - Total Reward: 1862.0
# Episode 686/1000 - Total Reward: 3714.0
# Episode 687/1000 - Total Reward: 8000.0
# Episode 688/1000 - Total Reward: 8000.0
# Episode 689/1000 - Total Reward: 6036.5
# Episode 690/1000 - Total Reward: 3642.5
# Episode 691/1000 - Total Reward: 8000.0
# Episode 692/1000 - Total Reward: 8000.0
# Episode 693/1000 - Total Reward: 6462.0
# Episode 694/1000 - Total Reward: 7403.5
# Episode 695/1000 - Total Reward: 4480.5
# Episode 696/1000 - Total Reward: 4351.5
# Episode 697/1000 - Total Reward: 5959.5
# Episode 698/1000 - Total Reward: 8000.0
# Episode 699/1000 - Total Reward: 7567.5
# Episode 700/1000 - Total Reward: 3614.5
# Episode 701/1000 - Total Reward: 7697.5
# Episode 702/1000 - Total Reward: 1583.0
# Episode 703/1000 - Total Reward: 8000.0
# Episode 704/1000 - Total Reward: 8000.0
# Episode 705/1000 - Total Reward: 8000.0
# Episode 706/1000 - Total Reward: 2543.0
# Episode 707/1000 - Total Reward: 6240.0
# Episode 708/1000 - Total Reward: 6862.5
# Episode 709/1000 - Total Reward: 2247.5
# Episode 710/1000 - Total Reward: 5015.5
# Episode 711/1000 - Total Reward: 6015.5
# Episode 712/1000 - Total Reward: 8000.0
# Episode 713/1000 - Total Reward: 7997.0
# Episode 714/1000 - Total Reward: 8000.0
# Episode 715/1000 - Total Reward: 5935.0
# Episode 716/1000 - Total Reward: 7573.5
# Episode 717/1000 - Total Reward: 4765.0
# Episode 718/1000 - Total Reward: 8000.0
# Episode 719/1000 - Total Reward: 1925.5
# Episode 720/1000 - Total Reward: 4816.0
# Episode 721/1000 - Total Reward: 8000.0
# Episode 722/1000 - Total Reward: 8000.0
# Episode 723/1000 - Total Reward: 8000.0
# Episode 724/1000 - Total Reward: 8000.0
# Episode 725/1000 - Total Reward: 3624.0
# Episode 726/1000 - Total Reward: 5623.5
# Episode 727/1000 - Total Reward: 3820.0
# Episode 728/1000 - Total Reward: 3530.5
# Episode 729/1000 - Total Reward: 4534.5
# Episode 730/1000 - Total Reward: 8000.0
# Episode 731/1000 - Total Reward: 1269.0
# Episode 732/1000 - Total Reward: 6114.0
# Episode 733/1000 - Total Reward: 1363.0
# Episode 734/1000 - Total Reward: 3033.0
# Episode 735/1000 - Total Reward: 5976.5
# Episode 736/1000 - Total Reward: 5455.0
# Episode 737/1000 - Total Reward: 2830.0
# Episode 738/1000 - Total Reward: 5882.5
# Episode 739/1000 - Total Reward: 8000.0
# Episode 740/1000 - Total Reward: 7317.5
# Episode 741/1000 - Total Reward: 4701.5
# Episode 742/1000 - Total Reward: 8000.0
# Episode 743/1000 - Total Reward: 7282.0
# Episode 744/1000 - Total Reward: 8000.0
# Episode 745/1000 - Total Reward: 3814.0
# Episode 746/1000 - Total Reward: 5311.0
# Episode 747/1000 - Total Reward: 8000.0
# Episode 748/1000 - Total Reward: 4772.5
# Episode 749/1000 - Total Reward: 2265.5
# Episode 750/1000 - Total Reward: 2086.0
# Episode 751/1000 - Total Reward: 7922.0
# Episode 752/1000 - Total Reward: 3972.0
# Episode 753/1000 - Total Reward: 1976.5
# Episode 754/1000 - Total Reward: 2935.0
# Episode 755/1000 - Total Reward: 8000.0
# Episode 756/1000 - Total Reward: 8000.0
# Episode 757/1000 - Total Reward: 6153.5
# Episode 758/1000 - Total Reward: 7300.0
# Episode 759/1000 - Total Reward: 8000.0
# Episode 760/1000 - Total Reward: 7462.0
# Episode 761/1000 - Total Reward: 8000.0
# Episode 762/1000 - Total Reward: 4109.5
# Episode 763/1000 - Total Reward: 7662.0
# Episode 764/1000 - Total Reward: 2388.5
# Episode 765/1000 - Total Reward: 3884.0
# Episode 766/1000 - Total Reward: 1947.0
# Episode 767/1000 - Total Reward: 8000.0
# Episode 768/1000 - Total Reward: 6502.5
# Episode 769/1000 - Total Reward: 2175.5
# Episode 770/1000 - Total Reward: 7997.0
# Episode 771/1000 - Total Reward: 6262.5
# Episode 772/1000 - Total Reward: 4887.5
# Episode 773/1000 - Total Reward: 2005.0
# Episode 774/1000 - Total Reward: 3988.0
# Episode 775/1000 - Total Reward: 7972.5
# Episode 776/1000 - Total Reward: 5845.5
# Episode 777/1000 - Total Reward: 8000.0
# Episode 778/1000 - Total Reward: 7950.0
# Episode 779/1000 - Total Reward: 7312.0
# Episode 780/1000 - Total Reward: 2797.5
# Episode 781/1000 - Total Reward: 8000.0
# Episode 782/1000 - Total Reward: 2970.5
# Episode 783/1000 - Total Reward: 7410.0
# Episode 784/1000 - Total Reward: 7968.0
# Episode 785/1000 - Total Reward: 7343.0
# Episode 786/1000 - Total Reward: 3510.5
# Episode 787/1000 - Total Reward: 6460.0
# Episode 788/1000 - Total Reward: 3141.5
# Episode 789/1000 - Total Reward: 2024.5
# Episode 790/1000 - Total Reward: 5095.0
# Episode 791/1000 - Total Reward: 5712.0
# Episode 792/1000 - Total Reward: 6776.0
# Episode 793/1000 - Total Reward: 7622.0
# Episode 794/1000 - Total Reward: 7982.0
# Episode 795/1000 - Total Reward: 8000.0
# Episode 796/1000 - Total Reward: 6505.0
# Episode 797/1000 - Total Reward: 2427.0
# Episode 798/1000 - Total Reward: 8000.0
# Episode 799/1000 - Total Reward: 2304.5
# Episode 800/1000 - Total Reward: 2682.5
# Episode 801/1000 - Total Reward: 8000.0
# Episode 802/1000 - Total Reward: 8000.0
# Episode 803/1000 - Total Reward: 8000.0
# Episode 804/1000 - Total Reward: 8000.0
# Episode 805/1000 - Total Reward: 2175.5
# Episode 806/1000 - Total Reward: 6219.5
# Episode 807/1000 - Total Reward: 5136.0
# Episode 808/1000 - Total Reward: 6962.0
# Episode 809/1000 - Total Reward: 3163.5
# Episode 810/1000 - Total Reward: 4813.0
# Episode 811/1000 - Total Reward: 5958.0
# Episode 812/1000 - Total Reward: 7993.0
# Episode 813/1000 - Total Reward: 3976.5
# Episode 814/1000 - Total Reward: 3846.5
# Episode 815/1000 - Total Reward: 7947.5
# Episode 816/1000 - Total Reward: 5768.5
# Episode 817/1000 - Total Reward: 8000.0
# Episode 818/1000 - Total Reward: 8000.0
# Episode 819/1000 - Total Reward: 4487.5
# Episode 820/1000 - Total Reward: 5499.0
# Episode 821/1000 - Total Reward: 8000.0
# Episode 822/1000 - Total Reward: 2864.0
# Episode 823/1000 - Total Reward: 7097.0
# Episode 824/1000 - Total Reward: 8000.0
# Episode 825/1000 - Total Reward: 6034.0
# Episode 826/1000 - Total Reward: 8000.0
# Episode 827/1000 - Total Reward: 6648.5
# Episode 828/1000 - Total Reward: 2951.5
# Episode 829/1000 - Total Reward: 2655.0
# Episode 830/1000 - Total Reward: 3738.5
# Episode 831/1000 - Total Reward: 3207.5
# Episode 832/1000 - Total Reward: 7995.5
# Episode 833/1000 - Total Reward: 7250.0
# Episode 834/1000 - Total Reward: 4288.5
# Episode 835/1000 - Total Reward: 7912.5
# Episode 836/1000 - Total Reward: 1786.0
# Episode 837/1000 - Total Reward: 6555.5
# Episode 838/1000 - Total Reward: 8000.0
# Episode 839/1000 - Total Reward: 2025.5
# Episode 840/1000 - Total Reward: 5612.0
# Episode 841/1000 - Total Reward: 3765.0
# Episode 842/1000 - Total Reward: 8000.0
# Episode 843/1000 - Total Reward: 7992.5
# Episode 844/1000 - Total Reward: 4813.5
# Episode 845/1000 - Total Reward: 6683.0
# Episode 846/1000 - Total Reward: 4463.0
# Episode 847/1000 - Total Reward: 5900.0
# Episode 848/1000 - Total Reward: 8000.0
# Episode 849/1000 - Total Reward: 2705.5
# Episode 850/1000 - Total Reward: 8000.0
# Episode 851/1000 - Total Reward: 7939.5
# Episode 852/1000 - Total Reward: 3124.0
# Episode 853/1000 - Total Reward: 5386.0
# Episode 854/1000 - Total Reward: 8000.0
# Episode 855/1000 - Total Reward: 8000.0
# Episode 856/1000 - Total Reward: 3140.5
# Episode 857/1000 - Total Reward: 4206.0
# Episode 858/1000 - Total Reward: 3447.0
# Episode 859/1000 - Total Reward: 7992.0
# Episode 860/1000 - Total Reward: 7803.5
# Episode 861/1000 - Total Reward: 7927.5
# Episode 862/1000 - Total Reward: 7855.5
# Episode 863/1000 - Total Reward: 8000.0
# Episode 864/1000 - Total Reward: 5646.5
# Episode 865/1000 - Total Reward: 2952.0
# Episode 866/1000 - Total Reward: 8000.0
# Episode 867/1000 - Total Reward: 5079.5
# Episode 868/1000 - Total Reward: 7786.0
# Episode 869/1000 - Total Reward: 8000.0
# Episode 870/1000 - Total Reward: 7892.0
# Episode 871/1000 - Total Reward: 8000.0
# Episode 872/1000 - Total Reward: 2796.5
# Episode 873/1000 - Total Reward: 2980.0
# Episode 874/1000 - Total Reward: 5001.0
# Episode 875/1000 - Total Reward: 7950.0
# Episode 876/1000 - Total Reward: 6149.0
# Episode 877/1000 - Total Reward: 6077.0
# Episode 878/1000 - Total Reward: 7361.0
# Episode 879/1000 - Total Reward: 5957.5
# Episode 880/1000 - Total Reward: 4465.5
# Episode 881/1000 - Total Reward: 2622.0
# Episode 882/1000 - Total Reward: 8000.0
# Episode 883/1000 - Total Reward: 8000.0
# Episode 884/1000 - Total Reward: 7447.5
# Episode 885/1000 - Total Reward: 6302.5
# Episode 886/1000 - Total Reward: 5206.0
# Episode 887/1000 - Total Reward: 4855.5
# Episode 888/1000 - Total Reward: 4498.0
# Episode 889/1000 - Total Reward: 8000.0
# Episode 890/1000 - Total Reward: 8000.0
# Episode 891/1000 - Total Reward: 7270.0
# Episode 892/1000 - Total Reward: 8000.0
# Episode 893/1000 - Total Reward: 3976.5
# Episode 894/1000 - Total Reward: 7923.5
# Episode 895/1000 - Total Reward: 5028.5
# Episode 896/1000 - Total Reward: 2262.5
# Episode 897/1000 - Total Reward: 6924.0
# Episode 898/1000 - Total Reward: 8000.0
# Episode 899/1000 - Total Reward: 8000.0
# Episode 900/1000 - Total Reward: 8000.0
# Episode 901/1000 - Total Reward: 6137.0
# Episode 902/1000 - Total Reward: 4265.0
# Episode 903/1000 - Total Reward: 8000.0
# Episode 904/1000 - Total Reward: 8000.0
# Episode 905/1000 - Total Reward: 2176.0
# Episode 906/1000 - Total Reward: 2418.0
# Episode 907/1000 - Total Reward: 3937.5
# Episode 908/1000 - Total Reward: 8000.0
# Episode 909/1000 - Total Reward: 5061.0
# Episode 910/1000 - Total Reward: 6882.5
# Episode 911/1000 - Total Reward: 4337.0
# Episode 912/1000 - Total Reward: 3330.5
# Episode 913/1000 - Total Reward: 2416.0
# Episode 914/1000 - Total Reward: 8000.0
# Episode 915/1000 - Total Reward: 5002.5
# Episode 916/1000 - Total Reward: 8000.0
# Episode 917/1000 - Total Reward: 2845.5
# Episode 918/1000 - Total Reward: 2008.0
# Episode 919/1000 - Total Reward: 6226.5
# Episode 920/1000 - Total Reward: 8000.0
# Episode 921/1000 - Total Reward: 2779.5
# Episode 922/1000 - Total Reward: 2839.0
# Episode 923/1000 - Total Reward: 8000.0
# Episode 924/1000 - Total Reward: 7855.5
# Episode 925/1000 - Total Reward: 8000.0
# Episode 926/1000 - Total Reward: 8000.0
# Episode 927/1000 - Total Reward: 8000.0
# Episode 928/1000 - Total Reward: 8000.0
# Episode 929/1000 - Total Reward: 8000.0
# Episode 930/1000 - Total Reward: 7742.0
# Episode 931/1000 - Total Reward: 2957.5
# Episode 932/1000 - Total Reward: 7702.0
# Episode 933/1000 - Total Reward: 8000.0
# Episode 934/1000 - Total Reward: 5487.0
# Episode 935/1000 - Total Reward: 6227.0
# Episode 936/1000 - Total Reward: 7982.0
# Episode 937/1000 - Total Reward: 8000.0
# Episode 938/1000 - Total Reward: 8000.0
# Episode 939/1000 - Total Reward: 6319.5
# Episode 940/1000 - Total Reward: 8000.0
# Episode 941/1000 - Total Reward: 7931.0
# Episode 942/1000 - Total Reward: 8000.0
# Episode 943/1000 - Total Reward: 8000.0
# Episode 944/1000 - Total Reward: 3887.5
# Episode 945/1000 - Total Reward: 5783.0
# Episode 946/1000 - Total Reward: 2120.0
# Episode 947/1000 - Total Reward: 7174.5
# Episode 948/1000 - Total Reward: 8000.0
# Episode 949/1000 - Total Reward: 7999.5
# Episode 950/1000 - Total Reward: 7982.0
# Episode 951/1000 - Total Reward: 6167.5
# Episode 952/1000 - Total Reward: 3096.5
# Episode 953/1000 - Total Reward: 5227.5
# Episode 954/1000 - Total Reward: 3063.5
# Episode 955/1000 - Total Reward: 8000.0
# Episode 956/1000 - Total Reward: 6718.0
# Episode 957/1000 - Total Reward: 3000.0
# Episode 958/1000 - Total Reward: 5496.0
# Episode 959/1000 - Total Reward: 2200.0
# Episode 960/1000 - Total Reward: 8000.0
# Episode 961/1000 - Total Reward: 8000.0
# Episode 962/1000 - Total Reward: 2467.0
# Episode 963/1000 - Total Reward: 8000.0
# Episode 964/1000 - Total Reward: 8000.0
# Episode 965/1000 - Total Reward: 8000.0
# Episode 966/1000 - Total Reward: 8000.0
# Episode 967/1000 - Total Reward: 7482.5
# Episode 968/1000 - Total Reward: 2975.5
# Episode 969/1000 - Total Reward: 1998.0
# Episode 970/1000 - Total Reward: 5380.0
# Episode 971/1000 - Total Reward: 7455.0
# Episode 972/1000 - Total Reward: 8000.0
# Episode 973/1000 - Total Reward: 6614.0
# Episode 974/1000 - Total Reward: 8000.0
# Episode 975/1000 - Total Reward: 3220.5
# Episode 976/1000 - Total Reward: 6309.0
# Episode 977/1000 - Total Reward: 1962.5
# Episode 978/1000 - Total Reward: 8000.0
# Episode 979/1000 - Total Reward: 8000.0
# Episode 980/1000 - Total Reward: 5859.5
# Episode 981/1000 - Total Reward: 3159.5
# Episode 982/1000 - Total Reward: 8000.0
# Episode 983/1000 - Total Reward: 7862.0
# Episode 984/1000 - Total Reward: 3522.5
# Episode 985/1000 - Total Reward: 4130.5
# Episode 986/1000 - Total Reward: 8000.0
# Episode 987/1000 - Total Reward: 3523.0
# Episode 988/1000 - Total Reward: 8000.0
# Episode 989/1000 - Total Reward: 8000.0
# Episode 990/1000 - Total Reward: 7972.5
# Episode 991/1000 - Total Reward: 2582.5
# Episode 992/1000 - Total Reward: 6530.5
# Episode 993/1000 - Total Reward: 3986.0
# Episode 994/1000 - Total Reward: 2979.5
# Episode 995/1000 - Total Reward: 2525.5
# Episode 996/1000 - Total Reward: 4667.5
# Episode 997/1000 - Total Reward: 7972.5
# Episode 998/1000 - Total Reward: 8000.0
# Episode 999/1000 - Total Reward: 4946.0
# Episode 1000/1000 - Total Reward: 5635.5

# %% [markdown]
# ### Evaluation

# %%
# Plotting the reward history over episodes
plt.plot(reward_history)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward Over Episodes')
plt.show()
